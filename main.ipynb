# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
car_noise_path='car_noise_specification_datasets.csv'
temp=pd.read_csv(car_noise_path,sep='\t',engine='python')
temp1=car_df.iloc[:,range(1,11)].copy()
noise_df=temp1.dropna(how='any')
columns=cars_df.columns.tolist()
temp
# Out:
#       Unnamed: 0   brand model           spec    year  dB_at_idle  \
# 0              0  Abarth   500  1.4 16v T-Jet  2008.0        47.3
# 1              1  Abarth   595   Competizione  2017.0        49.9
# 2              2   Acura   MDX         3.5 V6  2013.0        41.7
# 3              3   Acura   RDX         3.5 V6  2012.0        43.0
# 4              4   Acura    RL         3.7 V6  2009.0        43.6
# ...          ...     ...   ...            ...     ...         ...
# 1890        1890   Volvo  XC90           2.0d  2017.0        47.9
# 1891        1891   Volvo  XC90             T6  2017.0        39.9
# 1892        1892   Volvo  XC90             D4  2018.0        43.9
# 1893        1893   Volvo  XC90             D5  2018.0        47.1
# 1894        1894     NaN   NaN            NaN     NaN         NaN
#
#       dB_at_50kmh  dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  \
# 0            58.2         67.0          70.2          72.9  ...
# 1            65.7         69.0          72.3          73.1  ...
# 2            51.7         57.9          61.2          64.0  ...
# 3            54.4         61.5          65.5          67.7  ...
# 4            55.5         63.0          66.9          70.2  ...
# ...           ...          ...           ...           ...  ...
# 1890         64.7         65.5          66.3          67.2  ...
# 1891         55.8         60.0          64.3          65.2  ...
# 1892         53.5         59.1          64.3          66.7  ...
# 1893         55.6         60.9          65.3          67.7  ...
# 1894          NaN          NaN           NaN           NaN  ...
#
#       model_height_in_cqa  model_wheelbase_in_cqa  model_mpg_hwy_cqa  \
# 0                     NaN                     NaN                NaN
# 1                     NaN                     NaN                NaN
# 2                    68.2                   108.3               27.0
# 3                    65.1                   104.3               22.0
# 4                    57.5                   110.6               22.0
# ...                   ...                     ...                ...
# 1890                  NaN                     NaN                NaN
# 1891                  NaN                     NaN                NaN
# 1892                  NaN                     NaN                NaN
# 1893                  NaN                     NaN                NaN
# 1894                  NaN                     NaN                NaN
#
#      model_mpg_city_cqa model_mpg_mixed_cqa model_fuel_cap_g_cqa  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                  19.0                 NaN                 20.9
# 3                  17.0                 NaN                 18.0
# 4                  16.0                18.0                 19.3
# ...                 ...                 ...                  ...
# 1890                NaN                 NaN                  NaN
# 1891                NaN                 NaN                  NaN
# 1892                NaN                 NaN                  NaN
# 1893                NaN                 NaN                  NaN
# 1894                NaN                 NaN                  NaN
#
#       make_display_cqa make_country_cqa ExtColors_cqa  IntColors_cqa
# 0                  NaN              NaN           NaN            NaN
# 1                  NaN              NaN           NaN            NaN
# 2                Acura              USA           NaN            NaN
# 3                Acura              USA           NaN            NaN
# 4                Acura              USA           NaN            NaN
# ...                ...              ...           ...            ...
# 1890               NaN              NaN           NaN            NaN
# 1891               NaN              NaN           NaN            NaN
# 1892               NaN              NaN           NaN            NaN
# 1893               NaN              NaN           NaN            NaN
# 1894               NaN              NaN           NaN            NaN
#
# [1895 rows x 72 columns]

# %%
print(columns)
noise_df.head()
# Out:
# ['brand', 'model', 'spec', 'year', 'dB_at_idle', 'dB_at_50kmh', 'dB_at_80kmh', 'dB_at_100kmh', 'dB_at_120kmh', 'dB_at_140kmh']
#     brand model           spec    year  dB_at_idle  dB_at_50kmh  dB_at_80kmh  \
# 0  Abarth   500  1.4 16v T-Jet  2008.0        47.3         58.2         67.0
# 1  Abarth   595   Competizione  2017.0        49.9         65.7         69.0
# 2   Acura   MDX         3.5 V6  2013.0        41.7         51.7         57.9
# 3   Acura   RDX         3.5 V6  2012.0        43.0         54.4         61.5
# 4   Acura    RL         3.7 V6  2009.0        43.6         55.5         63.0
#
#    dB_at_100kmh  dB_at_120kmh  dB_at_140kmh
# 0          70.2          72.9          76.0
# 1          72.3          73.1          75.8
# 2          61.2          64.0          66.8
# 3          65.5          67.7          69.9
# 4          66.9          70.2          73.5

# %%
for col in noise_df.columns:
    print(col+'-----'+str(type(noise_df[col][0])))
# Out:
# brand-----<class 'str'>
# model-----<class 'str'>
# spec-----<class 'str'>
# year-----<class 'numpy.float64'>
# dB_at_idle-----<class 'numpy.float64'>
# dB_at_50kmh-----<class 'numpy.float64'>
# dB_at_80kmh-----<class 'numpy.float64'>
# dB_at_100kmh-----<class 'numpy.float64'>
# dB_at_120kmh-----<class 'numpy.float64'>
# dB_at_140kmh-----<class 'numpy.float64'>

# %%
noise_df['dB_at_idle'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-970409341fb3> in <module>
# ----> 1 noise_df['dB_at_idle'].as_type(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'as_type'

# %%
car_sales_path='Car_sales.csv'
temp_sales=pd.DataFrame(pd.read_csv(car_sales_path))
temp_sales2=temp_sales.drop(['__year_resale_value','Power_perf_factor','Wheelbase','Width','Length','Latest_Launch'],axis=1)
car_sales_df=temp_sales2.dropna(axis=0)
car_sales_df
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 3          Acura       RL               8.588    Passenger
# 4           Audi       A4              20.397    Passenger
# 5           Audi       A6              18.780    Passenger
# ..           ...      ...                 ...          ...
# 152        Volvo      V40               3.545    Passenger
# 153        Volvo      S70              15.245    Passenger
# 154        Volvo      V70              17.531    Passenger
# 155        Volvo      C70               3.493    Passenger
# 156        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Curb_weight  Fuel_capacity  \
# 0                 21.50          1.8       140.0        2.639           13.2
# 1                 28.40          3.2       225.0        3.517           17.2
# 3                 42.00          3.5       210.0        3.850           18.0
# 4                 23.99          1.8       150.0        2.998           16.4
# 5                 33.95          2.8       200.0        3.561           18.5
# ..                  ...          ...         ...          ...            ...
# 152               24.40          1.9       160.0        3.042           15.8
# 153               27.50          2.4       168.0        3.208           17.9
# 154               28.80          2.4       168.0        3.259           17.9
# 155               45.50          2.3       236.0        3.601           18.5
# 156               36.00          2.9       201.0        3.600           21.1
#
#      Fuel_efficiency
# 0               28.0
# 1               25.0
# 3               22.0
# 4               27.0
# 5               22.0
# ..               ...
# 152             25.0
# 153             25.0
# 154             25.0
# 155             23.0
# 156             24.0
#
# [152 rows x 10 columns]

# %%
for col in car_sales_df.columns:
    print(col+'-----'+str(type(car_sales_df[col][0])))
# Out:
# Manufacturer-----<class 'str'>
# Model-----<class 'str'>
# Sales_in_thousands-----<class 'numpy.float64'>
# Vehicle_type-----<class 'str'>
# Price_in_thousands-----<class 'numpy.float64'>
# Engine_size-----<class 'numpy.float64'>
# Horsepower-----<class 'numpy.float64'>
# Curb_weight-----<class 'numpy.float64'>
# Fuel_capacity-----<class 'numpy.float64'>
# Fuel_efficiency-----<class 'numpy.float64'>
